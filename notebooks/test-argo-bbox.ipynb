# %%
import argparse
import copy
import glob
import logging
import math
import multiprocessing
import os
import sys
from pathlib import Path
from typing import Any, Iterable, List, Mapping, Sequence, Tuple, Union

import cv2
import imageio
import matplotlib.pyplot as plt
import numpy as np

import PIL.Image as Image

import argoverse
from argoverse.utils import calibration
from argoverse.data_loading.object_label_record import json_label_dict_to_obj_record
from argoverse.data_loading.simple_track_dataloader import SimpleArgoverseTrackingDataLoader
from argoverse.map_representation.map_api import ArgoverseMap
from argoverse.data_loading.argoverse_tracking_loader import ArgoverseTrackingLoader
from argoverse.utils.calibration import (
    CameraConfig,
    get_calibration_config,
    point_cloud_to_homogeneous,
    project_lidar_to_img_motion_compensated,
    project_lidar_to_undistorted_img,
    load_calib,
    Calibration
)
from argoverse.utils.camera_stats import (
        RING_CAMERA_LIST,
        STEREO_CAMERA_LIST,
        RING_IMG_HEIGHT,
        RING_IMG_WIDTH
)
from argoverse.utils.city_visibility_utils import clip_point_cloud_to_visible_region
from argoverse.utils.cv2_plotting_utils import draw_clipped_line_segment
from argoverse.utils.ffmpeg_utils import write_nonsequential_idx_video
from argoverse.utils.frustum_clipping import (
        generate_frustum_planes,
        cuboid_to_2d_frustum_bbox
)
from argoverse.utils.ply_loader import load_ply
from argoverse.utils.se3 import SE3
import argoverse.visualization.visualization_utils as viz_util

# logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logger = logging.getLogger(__name__)

#: Any numeric type
Number = Union[int, float]

name_of_camera = 'ring_front_center'

# %%
a = [1,2,3,4]
a.sort()
a
# Out:
# [1, 2, 3, 4]

# %%
def overlaps(bbox1_xmin, bbox1_ymin, bbox1_xmax, bbox1_ymax, bbox2_xmin, bbox2_ymin, bbox2_xmax, bbox2_ymax, threshold=0.50):
#     print (bbox1_xmin, bbox1_ymin, bbox1_xmax, bbox1_ymax, bbox2_xmin, bbox2_ymin, bbox2_xmax, bbox2_ymax)
    if bbox1_xmin > bbox2_xmax or bbox2_xmin > bbox1_xmax: #gap in x
        return False
    elif bbox2_ymin > bbox2_ymax or bbox2_ymin > bbox1_ymax: #gap in y
        return False
    else: 
        area1 = (bbox1_xmax - bbox1_xmin)*(bbox1_ymax - bbox1_ymin)
        area2 = (bbox2_xmax - bbox2_xmin)*(bbox2_ymax - bbox2_ymin)
        xs = [bbox1_xmin,bbox1_xmax,bbox2_xmin,bbox2_xmax]
        ys = [bbox1_ymin,bbox1_ymax,bbox2_ymin,bbox2_ymax]
        xs.sort()
        ys.sort()
        if area1 == 0 or area2 == 0: 
            print (bbox1_xmin, bbox1_ymin, bbox1_xmax, bbox1_ymax, bbox2_xmin, bbox2_ymin, bbox2_xmax, bbox2_ymax)

        area_overlap = (xs[2] - xs[1])*(ys[2] - ys[1]) # interior points are always the overlaping ones
#         if max(area_overlap / area1 , area_overlap /area2) > threshold:
        if (area_overlap / area1) > threshold:
            return True
        else:
            return False
# 1710 572 1919 805 1919 558 1919 820
def shrink_box(bbox_xmin, bbox_ymin, bbox_xmax, bbox_ymax):
    x_avg = (bbox_xmin + bbox_xmax)/2
    y_avg = (bbox_ymin + bbox_ymax)/2
    return ((bbox_xmin + x_avg)/2, (bbox_ymin + y_avg)/2, (bbox_xmax + x_avg)/2, (bbox_ymax + y_avg)/2)
   
def ordering(uv1,xmin,ymin,xmax,ymax):
    uv1 = uv1.T
    xmin,ymin,xmax,ymax = shrink_box(xmin,ymin,xmax,ymax)
    lidar_bbox = uv1[(xmin < uv1[:,0]) & (uv1[:,0] < xmax)& (ymin < uv1[:,1]) & (uv1[:,1] < ymax)]
    if len(lidar_bbox[:,2]) != 0:
        return  np.mean(lidar_bbox[:,2])
    else:
        return 500
def pickle_format(bboxes,img):
    bboxes = [{'bbox': [xmin,xmax,ymin,ymax], 'label': label, 'id':track_id} for (xmin, ymin), (xmax, ymax),track_id,label , in bboxes]
    return {'center_camera_feed':img,'obstacles':bboxes}


def plot_img_2d_bboxes(
        labels,
        planes,
        img_bgr: np.ndarray,
        log_calib_data,
        camera_name: str,
        cam_timestamp: int,
        lidar_timestamp: int,
        data_dir: str,
        log_id: str,
        save_img_fpath: str,
        lidar_pts,
        show_depthmap = False
        
    
):
        """ """
        ############  Process lidar ###############
#         img = argoverse_data.get_image_sync(idx,camera = camera_name)
#         objects = argoverse_data.get_label_object(idx)
        
#         calib = argoverse_data.get_calibration(camera_name) # replace this with manual 
        
        cam_config = get_calibration_config(log_calib_data, camera_name)        
        calib_cam = next(
            (c for c in log_calib_data["camera_data_"] if c["key"] == f"image_raw_{camera_name}"),
            None,
        )
        if calib_cam is None:
            print (f"No Camera of name: {camera_name}")
        calib = Calibration(cam_config, calib_cam)
        
        
#         img_vis = viz_util.show_image_with_boxes(img,objects,calib)
#         display(Image.fromarray(img_vis))
        # ALMOST DEFINITELY OUT OF SYNC HERE
#         pc = argoverse_data.get_lidar(idx)
        pc = lidar_pts
        uv = calib.project_ego_to_image(pc).T
        

        idx_ = np.where(np.logical_and.reduce((uv[0, :] >= 0.0, uv[0, :] < np.shape(img_bgr)[1] - 1.0,
                                                          uv[1, :] >= 0.0, uv[1, :] < np.shape(img_bgr)[0] - 1.0,
                                                          uv[2, :] > 0)))

        # uv :: x , y , distance
        idx_ = idx_[0]

        uv1 =uv[:, idx_]

        if uv1 is None:
            raise Exception('No point image projection')

#         plt.figure(figsize=(10,30))
#         plt.imshow(img)
        
        
#         cm = plt.cm.get_cmap('jet')
#         plt.scatter(uv1[0], uv1[1], c=1 - uv1[2] / max(uv1[2]), s=1, cmap=cm)
#         plt.axis('off')
#         plt.savefig("base_"+save_img_fpath)
#         plt.clf()
#         assert 1 == 2
        
        bboxes = []
        print (len(labels))
        for label_idx, label in enumerate(labels):
                obj_rec = json_label_dict_to_obj_record(label)
                track_id = (obj_rec.track_id).replace("-","")
                track_id_short = int(track_id,16) % sys.maxsize
                if obj_rec.label_class in ["ANIMAL", "STROLLER", "OTHER_MOVER", "ON_ROAD_OBSTACLE"]:
                        continue                
                if obj_rec.occlusion == 100:
                        continue
                if obj_rec.occlusion > 0:
                        print("Occlusion {}".format(obj_rec.occlusion))
#                 print (obj_rec.label_class)
                cuboid_vertices = obj_rec.as_3d_bbox()
                points_h = point_cloud_to_homogeneous(cuboid_vertices).T

                uv, uv_cam, valid_pts_bool, camera_config = project_lidar_to_img_motion_compensated(
                        points_h,  # these are recorded at lidar_time
                        copy.deepcopy(log_calib_data),
                        camera_name,
                        cam_timestamp,
                        lidar_timestamp,
                        data_dir,
                        log_id,
                        return_K=True,
                )
                K = camera_config.intrinsic

                if valid_pts_bool.sum() == 0:
                    continue
                bbox_2d = cuboid_to_2d_frustum_bbox(uv_cam.T[:,:3], planes, K[:3,:3])
                if bbox_2d is None:
                        continue
                else:
                        x1,y1,x2,y2 = bbox_2d

                        x1 = min(x1,RING_IMG_WIDTH-1)
                        x2 = min(x2,RING_IMG_WIDTH-1)
                        y1 = min(y1,RING_IMG_HEIGHT-1)
                        y2 = min(y2,RING_IMG_HEIGHT-1)

                        x1 = max(x1, 0)
                        x2 = max(x2, 0)
                        y1 = max(y1, 0)
                        y2 = max(y2, 0)

                        xmin = min(x1, x2)
                        xmax = max(x1, x2)
                        ymin = min(y1, y2)
                        ymax = max(y1, y2)
                        start = (int(xmin), int(ymin))
                        end = (int(xmax), int(ymax))
                        if xmin != xmax and ymin != ymax: #get rid of zero area boxes
                            bboxes.append((start,end,track_id_short,obj_rec.label_class))
                        
                        
#                         cv2.rectangle(img_bgr, start, end, (0, 0, 255))

        average_depth = [ ordering(uv1, xmin,ymin,xmax,ymax) for (xmin,ymin),(xmax,ymax),_,_ in bboxes]
        new_bboxes = []
#         print (bboxes[40], bboxes[0])
#         (xmin,ymin), (xmax,ymax) = bboxes[40]
#         (x_min, y_min), (x_max,y_max) = bboxes[0]
#         print (overlaps(xmin,ymin,xmax,ymax,x_min,y_min,x_max,y_max))
        for i in range(len(bboxes)):
            (bbox1_xmin, bbox1_ymin), (bbox1_xmax, bbox1_ymax),bbox1_id,bbox1_label = bboxes[i]
            is_occluded = False
            for j  in range(len(bboxes)):
                if i != j:
                    (bbox2_xmin, bbox2_ymin), (bbox2_xmax, bbox2_ymax),_,_ = bboxes[j]
                    if overlaps(bbox1_xmin, bbox1_ymin, bbox1_xmax, bbox1_ymax, bbox2_xmin, bbox2_ymin, bbox2_xmax, bbox2_ymax):
                        is_occluded = is_occluded or (average_depth[j] < average_depth[i])
#                         print (f"{i} occludes {j}")
            if is_occluded == False:
                new_bboxes.append(((bbox1_xmin, bbox1_ymin), (bbox1_xmax, bbox1_ymax),bbox1_id,bbox1_label))

        for bbox_start, bbox_end, _,_ in new_bboxes:
            cv2.rectangle(img_bgr,bbox_start, bbox_end, (0,0,255))
        
        img = Image.fromarray(img_bgr[:,:,::-1])
        img.save(save_img_fpath)
        if show_depthmap:
            plt.imshow(img)        
            cm = plt.cm.get_cmap('jet')
            plt.scatter(uv1[0], uv1[1], c=1 - uv1[2] / max(uv1[2]), s=1, cmap=cm)
            plt.axis('off')
            plt.savefig("base_"+save_img_fpath)
            plt.clf()
        return pickle_format(new_bboxes,img)

# %%
def dump_log_2d_bboxes_to_imgs(
    log_ids: Sequence[str],
    max_num_images_to_render: int,
    data_dir: str,
    experiment_prefix: str,
    motion_compensate: bool = True,
) -> List[str]:
    """
    We bring the 3D points into each camera coordinate system, and do the clipping there in 3D.

    Args:
        log_ids: A list of log IDs
        max_num_images_to_render: maximum numbers of images to render.
        data_dir: path to dataset with the latest data
        experiment_prefix: Output directory
        motion_compensate: Whether to motion compensate when projecting

    Returns:
        saved_img_fpaths
    """
    saved_img_fpaths = []
    dl = SimpleArgoverseTrackingDataLoader(data_dir=data_dir, labels_dir=data_dir)
    avm = ArgoverseMap()

    for log_id in log_ids:
        save_dir = f"{experiment_prefix}_{log_id}"
        if not Path(save_dir).exists():
            os.makedirs(save_dir)
            
        # JUSTIN: For base image as I'm solivng sync issues
        if not Path("base_"+save_dir).exists():
            os.makedirs("base_"+save_dir)

        city_name = dl.get_city_name(log_id)
        log_calib_data = dl.get_log_calibration_data(log_id)

        flag_done = False
        for cam_idx, camera_name in enumerate(RING_CAMERA_LIST + STEREO_CAMERA_LIST):
            
            if camera_name != name_of_camera:
                continue

            print (dl.data_dir, log_id,camera_name)
            cam_im_fpaths = dl.get_ordered_log_cam_fpaths(log_id, camera_name)
            print (len(cam_im_fpaths), log_id, camera_name)
            
            
            ids = []
            for im_fpath in cam_im_fpaths:
                print (im_fpath)
                cam_timestamp = Path(im_fpath).stem.split("_")[-1]
                cam_timestamp = int(cam_timestamp)
                ply_fpath = dl.get_closest_lidar_fpath(log_id, cam_timestamp)
                if ply_fpath is None:
                    continue
                lidar_timestamp = Path(ply_fpath).stem.split("_")[-1]
                lidar_timestamp = int(lidar_timestamp)
                labels = dl.get_labels_at_lidar_timestamp(
                    log_id, lidar_timestamp)
                if labels is None:
                    logging.info("\tLabels missing at t=%s", lidar_timestamp)
                    continue
                for label in labels:
                    obj_rec = json_label_dict_to_obj_record(label)
                    track_id = (obj_rec.track_id).replace("-","")
                    ids.append(track_id)

            
            
            for i, im_fpath in enumerate(cam_im_fpaths):
                
                if i % 50 == 0:
                    logging.info("\tOn file %s of camera %s of %s", i, camera_name, log_id)

                cam_timestamp = Path(im_fpath).stem.split("_")[-1]
                cam_timestamp = int(cam_timestamp)

                # load PLY file path, e.g. 'PC_315978406032859416.ply'
                ply_fpath = dl.get_closest_lidar_fpath(log_id, cam_timestamp)
                if ply_fpath is None:
                    print ("break at no_fpath")
                    continue
                lidar_pts = load_ply(ply_fpath)# here we get lidar points
                

                
                
                save_img_fpath = f"{save_dir}/{camera_name}_{cam_timestamp}.jpg"
#                 save_img_fpath = f"{save_dir}/{camera_name}_{i}.jpg"
                print (f"Saving to {save_img_fpath}")
                if Path(save_img_fpath).exists():
                        print ("path exists exit")
                        continue

                city_to_egovehicle_se3 = dl.get_city_to_egovehicle_se3(log_id, cam_timestamp)
                if city_to_egovehicle_se3 is None:
                    print ("break at city_to_egovehicle")
                    continue

                lidar_timestamp = Path(ply_fpath).stem.split("_")[-1]
                lidar_timestamp = int(lidar_timestamp)
                labels = dl.get_labels_at_lidar_timestamp(log_id, lidar_timestamp)
                if labels is None:
                    logging.info("\tLabels missing at t=%s", lidar_timestamp)
                    print("break at missing label")
                    continue

                # Swap channel order as OpenCV expects it -- BGR not RGB
                # must make a copy to make memory contiguous
                img_bgr = imageio.imread(im_fpath)[:, :, ::-1].copy()
                camera_config = get_calibration_config(log_calib_data, camera_name)
                planes = generate_frustum_planes(camera_config.intrinsic.copy(), camera_name)

#                 print("We about to plot")
                plot_img_2d_bboxes(labels, planes, img_bgr, log_calib_data, 
                                   camera_name, cam_timestamp, lidar_timestamp, data_dir, 
                                   log_id, save_img_fpath,
                                   lidar_pts
                                  )

#                 print ("Finished plotting")
                if i > 400:
                        break

        category_subdir = "2d_amodal_labels_100fr"

        if not Path(f"{experiment_prefix}_{category_subdir}").exists():
            os.makedirs(f"{experiment_prefix}_{category_subdir}")

        for cam_idx, camera_name in enumerate(RING_CAMERA_LIST + STEREO_CAMERA_LIST):
            # Write the cuboid video -- could also write w/ fps=20,30,40
            if camera_name != name_of_camera:
                continue
            if "stereo" in camera_name:
                fps = 5
            else:
                fps = 30
            img_wildcard = f"{save_dir}/{camera_name}_%*.jpg"
            output_fpath = f"{experiment_prefix}_{category_subdir}/{log_id}_{camera_name}_{fps}fps.mp4"

            write_nonsequential_idx_video(img_wildcard, output_fpath, fps)

            print (img_wildcard, output_fpath,fps)
            print ("###################### HERE #####################")

# %%
# def main(args: Any):
#     """Run the example."""
#     log_ids = [log_id.strip() for log_id in args.log_ids.split(",")]
#     dump_log_2d_bboxes_to_imgs(
#         log_ids, args.max_num_images_to_render * 9, args.dataset_dir, args.experiment_prefix
#     )


# if __name__ == "__main__":
#     # Parse command line arguments
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#         "--max-num-images-to-render", default=5, type=int, help="number of images within which to render 3d cuboids"
#     )
#     parser.add_argument("--dataset-dir", type=str, required=True, help="path to the dataset folder")
#     parser.add_argument(
#         "--log-ids",
#         type=str,
#         required=True,
#         help="comma separated list of log ids, each log_id represents a log directory, e.g. found at "
#         " {args.dataset-dir}/argoverse-tracking/train/{log_id} or "
#         " {args.dataset-dir}/argoverse-tracking/sample/{log_id} or ",
#     )
#     parser.add_argument(
#         "--experiment-prefix",
#         default="output",
#         type=str,
#         help="results will be saved in a folder with this prefix for its name",
#     )
#     args = parser.parse_args()
#     logger.info(args)

#     if args.log_ids is None:
#         logger.error(f"Please provide a comma seperated list of log ids")
#         raise ValueError(f"Please provide a comma seperated list of log ids")

#     main(args)
log_ids = ['6f153f9c-edc5-389f-ac6f-40705c30d97e']
max_num_images_to_render = 1
dataset_dir = '/data/wong.justin/argo/argoverse-tracking/train1/'
experiment_prefix = 'depth'
dump_log_2d_bboxes_to_imgs(log_ids,max_num_images_to_render*9, dataset_dir, experiment_prefix)
# Out:
# /data/wong.justin/argo/argoverse-tracking/train1/ 6f153f9c-edc5-389f-ac6f-40705c30d97e ring_front_center
# 463 6f153f9c-edc5-389f-ac6f-40705c30d97e ring_front_center
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434214396776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434247696632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434280996408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434314296296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434347596072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434380895928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434414195816.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434447495592.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434480795368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434514095336.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434547395112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434580694888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434613994776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434647294632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434680594408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434713894296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434747194072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434780493928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434813793816.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434847093592.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434880393368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434913693336.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434946993112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966434980292888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435013592776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435046892632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435080192408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435113492296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435146792072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435180091928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435213391816.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435246691592.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435279991368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435313291256.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435346591112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435379890888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435413190776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435446490552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435479790408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435513090296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435546390072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435579689960.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435612989736.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435646289592.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435679589480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435712889312.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435746189480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435779489704.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435812789952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435846090120.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435879390344.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435912690512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435945990680.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966435979290984.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436012591152.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436045891320.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436079191544.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436112491792.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436145791960.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436179092184.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436212392352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436245692520.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436278992824.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436312292992.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436345593160.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436378893384.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436412193632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436445493800.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436478794024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436512094192.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436545394440.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436578694664.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436611994832.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436645295000.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436678595304.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436711895472.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436745195640.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436778495864.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436811796032.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436845096280.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436878396504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436911696672.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436944996840.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966436978297064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437011597312.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437044897480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437078197704.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437111497872.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437144798040.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437178098264.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437211398368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437244698208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437277997928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437311297648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437344597568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437377897288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437411197008.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437444496848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437477796568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437511096368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437544396208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437577695928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437610995648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437644295488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437677595288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437710895008.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437744194848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437777494568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437810794288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437844094128.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437877393848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437910693648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437943993488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966437977293208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438010592928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438043892768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438077192568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438110492288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438143792128.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438177091848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438210391648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438243691488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438276991208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438310290928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438343590768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438376890568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438410190288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438443490128.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438476789848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438510089648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438543389488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438576689208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438609988928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438643288768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438676588568.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438709888352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438743188576.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438776488744.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438809788992.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438843089216.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438876389384.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438909689608.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438942989856.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966438976290024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439009590248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439042890416.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439076190584.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439109490888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439142791056.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439176091224.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439209391448.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439242691616.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439275991864.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439309292088.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439342592256.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439375892424.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439409192728.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439442492896.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439475793064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439509093288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439542393456.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439575693704.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439608993928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439642294176.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439675594344.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439708894648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439742194816.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439775494984.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439808795208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439842095456.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439875395624.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439908695848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439941996016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966439975296264.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440008596488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440041896656.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440075196824.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440108497128.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440141797296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440175097464.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440208397688.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440241697544.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440274997320.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440308297208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440341596984.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440374896760.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440408196728.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440441496504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440474796280.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440508096168.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440541395944.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440574695800.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440607995688.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440641295464.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440674595352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440707895208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440741194984.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440774494872.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440807794648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440841094504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440874394392.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440907694248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440940994024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966440974293912.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441007593768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441040893544.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441074193432.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441107493208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441140793064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441174092952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441207392728.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441240692504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441273992472.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441307292248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441340592024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441373891912.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441407191768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441440491544.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441473791432.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441507091208.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441540391064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441573690952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441606990808.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441640290664.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441673590552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441706890408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441740190520.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441773490696.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441806790888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441840091000.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441873391176.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441906691288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441939991480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966441973291656.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442006591768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442039891880.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442073192056.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442106492248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442139792360.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442173092536.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442206392648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442239692840.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442272993016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442306293128.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442339593304.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442372893416.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442406193528.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442439493784.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442472793896.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442506094008.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442539394184.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442572694296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442605994488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442639294664.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442672594776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442705894888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442739195064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442772495176.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442805795368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442839095544.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442872395656.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442905695768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442938995944.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966442972296136.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443005596248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443038896424.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443072196536.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443105496648.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443138796824.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443172097016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443205397080.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443238696968.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443271996744.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443305296600.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443338596488.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443371896264.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443405196040.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443438495928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443471795784.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443505095560.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443538395448.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443571695224.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443604995000.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443638294888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443671594744.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443704894520.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443738194408.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443771494184.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443804793960.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443838093928.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443871393704.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443904693480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443937993368.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966443971293144.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444004593032.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444037892888.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444071192664.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444104492552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444137792328.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444171092104.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444204391992.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444237691848.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444270991624.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444304291512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444337591288.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444370891064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444404190952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444437490728.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444470790584.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444504090472.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444537390248.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444570690024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444603989912.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444637289688.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444670589464.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444703889352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444737189520.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444770489768.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444803789992.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444837090160.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444870390328.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444903690552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444936990720.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966444970290968.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966445003591192.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966445036891360.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966445070191528.jpg
# ...
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446202398232.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446235697952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446268997792.jpg
# WARNING:argoverse.data_loading.synchronization_database:No corresponding LiDAR sweep: 79.803392 > 51.0 ms
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446302297512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446335597232.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446368897072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446402196792.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446435496512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446468796352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446502096072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446535395792.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446568695632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446601995352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446635295072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446668594832.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446701894552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446735194272.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446768494112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446801793832.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446835093552.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446868393392.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446901693112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446934992832.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966446968292672.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447001592392.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447034892112.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447068191952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447101491672.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447134791392.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447168091232.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447201390952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447234690672.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447267990512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447301290232.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447334589952.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447367889792.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447401189512.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447434489352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447467789072.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447501088792.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447534388632.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447567688352.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447600988152.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447634287992.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447667587712.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447700887504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447734187776.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447767488000.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447800788224.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447834088496.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447867388800.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447900689024.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447933989296.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966447967289520.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448000589744.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448033890016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448067190240.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448100490464.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448133790736.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448167090960.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448200391184.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448233691456.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448266991680.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448300291904.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448333592176.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448366892400.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448400192624.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448433492816.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448466793040.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448500093264.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448533393456.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448566693600.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448599993824.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448633294016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448666594160.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448699894384.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448733194576.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448766494720.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448799794944.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448833095136.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448866395280.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448899695504.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448932995696.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448966295920.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966448999596064.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449032896336.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449066196480.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449099496672.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449132796896.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449166097120.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449199397312.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449232697144.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449265996976.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449299296832.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449332596664.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449365896496.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449399196432.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449432496184.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449465796016.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449499095872.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449532395704.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449565695456.jpg
# /data/wong.justin/argo/argoverse-tracking/train1//6f153f9c-edc5-389f-ac6f-40705c30d97e/ring_front_center/ring_front_center_315966449598995392.jpg
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-327e89a694c6> in <module>
#      40 dataset_dir = '/data/wong.justin/argo/argoverse-tracking/train1/'
#      41 experiment_prefix = 'depth'
# ---> 42 dump_log_2d_bboxes_to_imgs(log_ids,max_num_images_to_render*9, dataset_dir, experiment_prefix)
#
# <ipython-input-18-ee9ea804b0ea> in dump_log_2d_bboxes_to_imgs(log_ids, max_num_images_to_render, data_dir, experiment_prefix, motion_compensate)
#      65                     track_id = (obj_rec.track_id).replace("-","")
#      66                     ids.append(track_id)
# ---> 67             assert 1 == 2
#      68
#      69
#
# AssertionError:

# %%
import sys
sys.maxsize
# Out:
# 9223372036854775807

# %%
a = np.array([0,1,2,6])
dict([(id, i)for i, id in enumerate(a)])
# Out:
# {0: 0, 1: 1, 2: 2, 6: 3}
