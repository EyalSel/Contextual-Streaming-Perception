# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ranking_config_params = [
    ('Track min IOU', 0.1290611478437975),
    ('Det model arch', 0.10896958),
    ('Track reinit freq', 0.05027186716949325),
    ('Track max age', 0.028925661351701527),
    ('Det sched policy', 0.002405218),    
    ('Det confidence thres', 0.0015687080852832306),
]

plt.figure(figsize=(5, 1.5))
plt.bar([x[0] for x in ranking_config_params], np.array([x[1] for x in ranking_config_params])/ranking_config_params[0][1])
plt.xticks(rotation=30, fontsize=12)
plt.yticks(fontsize=12)
plt.savefig("ranking_config_params.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
ranking_det_model = [
    ('edet-d7x', 0.02493305552805209),
    ('edet-d1', 0.02395026721206637),
    ('edet-d7', 0.021640956078897145),
    ('edet-d2', 0.015620983979249402),
    ('edet-d4', 0.007949189632385686),
    ('edet-d3', 0.0059778680817298745),
    ('edet-d6', 0.004603227571017139),
    ('edet-d5', 0.004294031899621557),
]

plt.figure(figsize=(5, 1.5))
plt.bar([x[0] for x in ranking_det_model], np.array([x[1] for x in ranking_det_model])/ranking_det_model[0][1])
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.savefig("ranking_det_model.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
ranking_env_features = [
     ('bbox size', 0.186173924),
     ('bbox longevity', 0.169254843),
     ('num bboxes', 0.147397652),
     ('bbox speed', 0.081385214),
     ('vehicle speed', 0.07044551330074564),
     ('location', 0.018278079),
     ('time of day', 0.005862592)
]

plt.figure(figsize=(5, 1.5))
plt.bar([x[0] for x in ranking_env_features], np.array([x[1] for x in ranking_env_features])/ranking_env_features[0][1])
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.savefig("ranking_env_features.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
avg_mota_per_det_model = [
    ("edet-d1", 12.303278644093009),
    ("edet-d2", 15.146456209084683),
    ("edet-d3", 17.304500414527155),
    ("edet-d4", 19.05195601962738),
    ("edet-d5", 15.789711149623761),
    ("edet-d6", 15.875530458114161),
    ("edet-d7", 11.755234251783156),
    ("edet-d7x", 12.153144655596243),
]

plt.figure(figsize=(5, 1.5))
plt.bar([x[0] for x in avg_mota_per_det_model], np.array([x[1] for x in avg_mota_per_det_model]))
plt.ylabel("Timely Mota")
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.savefig("avg_mota_per_det_model.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
per_scenario_oracle_proportions_all = {
    "D_model_name": (['edet-d2', 'edet-d3', 'edet-d4',
           'edet-d5', 'edet-d6', 'edet-d7',
           'edet-d7x'], [ 3,  8, 53, 12, 13, 13, 46]),
    "D-conf": ([0.3, 0.5], [73, 75]),
    "D-seq-pol": (['eager', 'tail-aware', 'wait'], [57, 42, 49]),
    "T-min-iou": ([0.1, 0.2, 0.5], [141,   1,   6]),
    "T-max-age": ([1, 3, 5, 7], [30, 26, 21, 71]),
    "T-every-nth-det": ([1., 3., 5.], [140,   3,   5]),
}

per_scenario_oracle_proportions_test = {
    "D_model_name": (['edet-d3', 'edet-d4', 'edet-d5',
           'edet-d6', 'edet-d7', 'edet-d7x'], [ 2, 16,  5,  5,  4, 17]),
    "D-conf": ([0.3, 0.5], [26, 23]),
    "D-seq-pol": (['eager', 'tail-aware', 'wait'], [17, 12, 20]),
    "T-min-iou": ([0.1, 0.5], [48,  1]),
    "T-max-age": ([1, 3, 5, 7], [ 7, 10,  7, 25]),
    "T-every-nth-det": ([1., 5.], [47,  2]),
}

per_scenario_oracle_proportions_train = {
    "D_model_name": (['edet-d2', 'edet-d3', 'edet-d4',
           'edet-d5', 'edet-d6', 'edet-d7',
           'edet-d7x'], [ 2,  7, 37,  7,  8,  7, 31]),
    "D-conf": ([0.3, 0.5], [47, 52]),
    "D-seq-pol": (['eager', 'tail-aware', 'wait'], [36, 27, 36]),
    "T-min-iou": ([0.1, 0.2, 0.5], [94,  1,  4]),
    "T-max-age": ([1, 3, 5, 7], [21, 21, 12, 45]),
    "T-every-nth-det": ([1., 3., 5.], [94,  1,  4]),
}

train_test_model_proportions = {
    "D_model_name": (['edet-d2', 'edet-d4', 'edet-d5',
           'edet-d6', 'edet-d7x'], [ 1, 32,  6,  2,  8]),
    "D-conf": ([0.3, 0.5], [17, 32]),
    "D-seq-pol": (['eager', 'tail-aware', 'wait'], [10, 24, 15]),
    "T-min-iou": ([0.1], [49]),
    "T-max-age": ([1, 3, 5, 7], [14, 13, 13,  9]),
    "T-every-nth-det": ([1], [49]),
}

train_train_model_proportions = {
    "D_model_name": (['edet-d2', 'edet-d3', 'edet-d4',
           'edet-d5', 'edet-d6', 'edet-d7',
           'edet-d7x'], [ 1,  8, 41,  7,  9,  3, 30]),
    "D-conf": ([0.3, 0.5], [47, 52]),
    "D-seq-pol": (['eager', 'tail-aware', 'wait'], [30, 33, 36]),
    "T-min-iou": ([0.1], [99]),
    "T-max-age": ([1, 3, 5, 7], [24, 18, 15, 42]),
    "T-every-nth-det": ([1, 5], [98,  1]),
}

# %%
plt.figure(figsize=(5,5))
shared_keys = set.union(set(per_scenario_oracle_proportions.keys()), set(trained_model_proportions.keys()))
for i, k in enumerate(shared_keys):
#     plt.subplot(len(shared_keys), 1, i+1)
    plt.subplot(3, len(shared_keys)/3, i+1)
    plt.xlabel(k)
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.bar(per_scenario_oracle_proportions_train[k][0], np.array(per_scenario_oracle_proportions_train[k][1])/np.sum(per_scenario_oracle_proportions_train[k][1]), alpha=0.3, label="Oracle")
    plt.bar(train_train_model_proportions[k][0], np.array(train_train_model_proportions[k][1])/np.sum(train_train_model_proportions[k][1]), alpha=0.3, label="Learned")
    if i == 1:
        plt.legend()
plt.tight_layout()
# plt.savefig("proportions_train_and_oracle.pdf", format="pdf", bbox_inches='tight')
plt.show()
# Out:
# /data/ges/miniconda3/envs/erdos_env/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   """

# %%
plt.figure(figsize=(5,5))
shared_keys = set.union(set(per_scenario_oracle_proportions.keys()), set(trained_model_proportions.keys()))
for i, k in enumerate(shared_keys):
#     plt.subplot(len(shared_keys), 1, i+1)
    plt.subplot(3, len(shared_keys)/3, i+1)
    plt.xlabel(k)
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.bar(per_scenario_oracle_proportions_test[k][0], np.array(per_scenario_oracle_proportions_test[k][1])/np.sum(per_scenario_oracle_proportions_test[k][1]), alpha=0.3, label="Oracle")
    plt.bar(train_test_model_proportions[k][0], np.array(train_test_model_proportions[k][1])/np.sum(train_test_model_proportions[k][1]), alpha=0.3, label="Learned")
    if i == 1:
        plt.legend()
plt.tight_layout()
# plt.savefig("proportions_train_and_oracle.pdf", format="pdf", bbox_inches='tight')
plt.show()
# Out:
# /data/ges/miniconda3/envs/erdos_env/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   """
